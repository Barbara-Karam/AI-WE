# %%
u = "hello world"
print(u)
u = 5.5
print(u)
u="c"
print(u)
u=True
print(u)
# Out:
# hello world
# 5.5
# c
# True

# %%
5*9
# Out:
# 45

# %%
import numpy as np
np.array([1,2,3,4],dtype='float32')
# Out:
# array([1., 2., 3., 4.], dtype=float32)

# %%
import numpy as np
np.array([1,2,3,4],dtype='str')
# Out:
# array(['1', '2', '3', '4'], dtype='<U1')

# %%
import numpy as np
np.array([1.9,2.01,3.5,4.0],dtype='int')
# Out:
# array([1, 2, 3, 4])

# %%
import pandas as pd
obj=pd.Series([1,"whatevs",3.56,"h"])
obj
# Out:
# 0          1
# 1    whatevs
# 2       3.56
# 3          h
# dtype: object

# %%
obj[3]
# Out:
# 'h'

# %%
obj.values
# Out:
# array([1, 'whatevs', 3.56, 'h'], dtype=object)

# %%
import pandas as pd
obj=pd.Series([1,"whatevs",3.56,"h"],index=)
obj

# %%
games=pd.read_csv("vgsalesGlobale.csv")
games.head(10)
games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
games.Genre.describe()
# Out:
# count      16598
# unique        12
# top       Action
# freq        3316
# Name: Genre, dtype: object

# %%
games.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
games.Genre.value_counts().tail()
# Out:
# Platform      886
# Simulation    867
# Fighting      848
# Strategy      681
# Puzzle        582
# Name: Genre, dtype: int64

# %%
import matplotlib.pyplot as plt
games.Global_Sales.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
games.Year.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
games.Year.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
games.NA_Sales.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
games.Publisher.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
games.Publisher.value_counts().head().plot(kind="bar")
# Out:
# <Axes: >

# %%
data = {
    "name" : ["Bill","someone","somebody","C-something"],
    "score": [50,65,62,99],
    "Subject":["Maths","Science","Computer Science","Physica Education"],
    "Gender":["F","M","M","F"]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#           name  score            Subject Gender
# 0         Bill     50              Maths      F
# 1      someone     65            Science      M
# 2     somebody     62   Computer Science      M
# 3  C-something     99  Physica Education      F

# %%
df.Gender.values
# Out:
# array(['F', 'M', 'M', 'F'], dtype=object)

# %%
df.score.value_counts()
# Out:
# 50    1
# 65    1
# 62    1
# 99    1
# Name: score, dtype: int64

# %%
df["score"]=40,55,66,80

# %%
df["pass"]=df.score>=50

# %%
df
# Out:
#           name  score            Subject Gender   pass
# 0         Bill     40              Maths      F  False
# 1      someone     55            Science      M   True
# 2     somebody     66   Computer Science      M   True
# 3  C-something     80  Physica Education      F   True

# %%
df.loc[0]
# Out:
# name        Bill
# score         40
# Subject    Maths
# Gender         F
# pass       False
# Name: 0, dtype: object

# %%
del df['pass']

# %%
df
# Out:
#           name  score            Subject Gender
# 0         Bill     40              Maths      F
# 1      someone     55            Science      M
# 2     somebody     66   Computer Science      M
# 3  C-something     80  Physica Education      F

# %%
df["pass"]=df.score>=50
df
# Out:
#           name  score            Subject Gender   pass
# 0         Bill     40              Maths      F  False
# 1      someone     55            Science      M   True
# 2     somebody     66   Computer Science      M   True
# 3  C-something     80  Physica Education      F   True

# %%
df["good"]=df.score>=75
df["excellent"]=df.score>=90
df
# Out:
#           name  score            Subject Gender   pass   good  excelent  \
# 0         Bill     40              Maths      F  False  False     False
# 1      someone     55            Science      M   True  False     False
# 2     somebody     66   Computer Science      M   True  False     False
# 3  C-something     80  Physica Education      F   True   True     False
#
#    excellent
# 0      False
# 1      False
# 2      False
# 3      False
